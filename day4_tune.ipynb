# %%
from google import genai
from google.genai import types

genai.__version__
import os
GOOGLE_API_KEY = os.getenv("GOOGLE_API_KEY")

if GOOGLE_API_KEY is None:
    raise ValueError("GOOGLE_API_KEY is not set. Set it as an environment variable.")

# %%
client = genai.Client(api_key=GOOGLE_API_KEY)
for model in client.models.list():
    if "createTunedModel" in model.supported_actions:
        print(model.name)
# Out:
# models/gemini-1.5-flash-001-tuning

# %%
from sklearn.datasets import fetch_20newsgroups

newsgroups_train = fetch_20newsgroups(subset="train")
newsgroups_test = fetch_20newsgroups(subset="test")

# View list of class names for dataset
newsgroups_train.target_names
# Out:
# ['alt.atheism',
#  'comp.graphics',
#  'comp.os.ms-windows.misc',
#  'comp.sys.ibm.pc.hardware',
#  'comp.sys.mac.hardware',
#  'comp.windows.x',
#  'misc.forsale',
#  'rec.autos',
#  'rec.motorcycles',
#  'rec.sport.baseball',
#  'rec.sport.hockey',
#  'sci.crypt',
#  'sci.electronics',
#  'sci.med',
#  'sci.space',
#  'soc.religion.christian',
#  'talk.politics.guns',
#  'talk.politics.mideast',
#  'talk.politics.misc',
#  'talk.religion.misc']

# %%
print(newsgroups_train.data[0])
# Out:
# From: lerxst@wam.umd.edu (where's my thing)
# Subject: WHAT car is this!?
# Nntp-Posting-Host: rac3.wam.umd.edu
# Organization: University of Maryland, College Park
# Lines: 15
#
#  I was wondering if anyone out there could enlighten me on this car I saw
# the other day. It was a 2-door sports car, looked to be from the late 60s/
# early 70s. It was called a Bricklin. The doors were really small. In addition,
# the front bumper was separate from the rest of the body. This is
# all I know. If anyone can tellme a model name, engine specs, years
# of production, where this car is made, history, or whatever info you
# have on this funky looking car, please e-mail.
#
# Thanks,
# - IL
#    ---- brought to you by your neighborhood Lerxst ----

# %%
import email
import re

import pandas as pd


def preprocess_newsgroup_row(data):
    # Extract only the subject and body
    msg = email.message_from_string(data)
    text = f"{msg['Subject']}\n\n{msg.get_payload()}"
    # Strip any remaining email addresses
    text = re.sub(r"[\w\.-]+@[\w\.-]+", "", text)
    # Truncate the text to fit within the input limits
    text = text[:40000]

    return text

def preprocess_newsgroup_data(newsgroup_dataset):
    # Put data points into dataframe
    df = pd.DataFrame(
        {"Text": newsgroup_dataset.data, "Label": newsgroup_dataset.target}
    )
    # Clean up the text
    df["Text"] = df["Text"].apply(preprocess_newsgroup_row)
    # Match label to target name index
    df["Class Name"] = df["Label"].map(lambda l: newsgroup_dataset.target_names[l])

    return df

# %%
# Apply preprocessing to training and test datasets
df_train = preprocess_newsgroup_data(newsgroups_train)
df_test = preprocess_newsgroup_data(newsgroups_test)

df_train.head()
# Out:
#                                                 Text  Label  \
# 0  WHAT car is this!?\n\n I was wondering if anyo...      7
# 1  SI Clock Poll - Final Call\n\nA fair number of...      4
# 2  PB questions...\n\nwell folks, my mac plus fin...      4
# 3  Re: Weitek P9000 ?\n\nRobert J.C. Kyanko () wr...      1
# 4  Re: Shuttle Launch Question\n\nFrom article <>...     14
#
#               Class Name
# 0              rec.autos
# 1  comp.sys.mac.hardware
# 2  comp.sys.mac.hardware
# 3          comp.graphics
# 4              sci.space

# %%
def sample_data(df, num_samples, classes_to_keep):
    # Sample rows, selecting num_samples of each Label.
    df = (
        df.groupby("Label")[df.columns]
        .apply(lambda x: x.sample(num_samples))
        .reset_index(drop=True)
    )

    df = df[df["Class Name"].str.contains(classes_to_keep)]
    df["Class Name"] = df["Class Name"].astype("category")

    return df

TRAIN_NUM_SAMPLES = 50
TEST_NUM_SAMPLES = 10
# Keep rec.* and sci.*
CLASSES_TO_KEEP = "^rec|^sci"

df_train = sample_data(df_train, TRAIN_NUM_SAMPLES, CLASSES_TO_KEEP)
df_test = sample_data(df_test, TEST_NUM_SAMPLES, CLASSES_TO_KEEP)

# %%
sample_idx = 0
sample_row = preprocess_newsgroup_row(newsgroups_test.data[sample_idx])
sample_label = newsgroups_test.target_names[newsgroups_test.target[sample_idx]]

print(sample_row)
print('---')
print('Label:', sample_label)
# Out:
# Need info on 88-89 Bonneville
#
#
#  I am a little confused on all of the models of the 88-89 bonnevilles.
# I have heard of the LE SE LSE SSE SSEI. Could someone tell me the
# differences are far as features or performance. I am also curious to
# know what the book value is for prefereably the 89 model. And how much
# less than book value can you usually get them for. In other words how
# much are they in demand this time of year. I have heard that the mid-spring
# early summer is the best time to buy.
#
# 			Neil Gandler
#
# ---
# Label: rec.autos

# %%
response = client.models.generate_content(
    model="gemini-1.5-flash-001", contents=sample_row)
print(response.text)
# Out:
# ## 1988-1989 Pontiac Bonnevilles: A Breakdown
#
# You're right, the 1988-1989 Bonneville lineup can be a bit confusing with all the different trim levels! Here's a breakdown to help you:
#
# **Base Model:**
# * The most basic Bonneville, often just called "Bonneville."
# * Typically featured the 3.8L V6 engine and a standard 3-speed automatic transmission.
# * Fewer standard features compared to higher trims.
#
# **LE (Luxury Edition):**
# * Added luxury features like power windows, locks, and mirrors.
# * Usually came with cloth upholstery and a few more comfort amenities.
#
# **SE (Special Edition):**
# *  A sportier trim level with a more aggressive exterior design.
# *  Often included features like a sunroof and special wheels.
# *  Might have had the optional 5.0L V8 engine.
#
# **LSE (Luxury Special Edition):**
# *  Combined the luxury of the LE with the sportier features of the SE.
# *  Usually came with leather upholstery, a sunroof, and the 5.0L V8.
#
# **SSE (Sport Special Edition):**
# *  The top-of-the-line performance trim.
# *  Featured the 5.0L V8 engine, stiffer suspension, and unique exterior and interior styling.
# *  Often included sport seats, a performance steering wheel, and other sporty features.
#
# **SSEi (Sport Special Edition, Injection):**
# *  This was a rare trim level only available in 1989.
# *  Featured a fuel-injected 5.0L V8 engine for improved performance and fuel economy.
# *  Had all the features of the regular SSE and more.
#
# **Book Value & Market Demand:**
#
# *  **Book Value:**  It's tough to give an exact book value without knowing the specific condition, mileage, and options of the car you're interested in. Websites like Kelley Blue Book (KBB) or Edmunds can give you a general idea based on the car's details.
# * **Market Demand:**  Demand for classic Bonnevilles can vary, but they are generally not in high demand. While the 1988-1989 models aren't considered classics, their value is influenced by condition, mileage, and trim level.
# * **Negotiation:**  You can often get a price lower than the book value. It's always best to negotiate and research what similar vehicles are selling for in your area.
#
# **Best Time to Buy:**
#
# *  While mid-spring to early summer can be a good time for buying cars, remember that market conditions fluctuate.
# *  Consider:
#     * **Holidays:**  Dealerships often run sales during major holidays.
#     * **End of the Month/Quarter:** Salespeople might be more motivated to close deals at the end of these periods.
#     * **Inventory Levels:**  If dealerships have excess inventory, they may be more open to negotiation.
#
# **Additional Considerations:**
#
# *  **Maintenance and Parts:** Be prepared for potential maintenance costs. Older vehicles require regular servicing and parts can be harder to find or more expensive.
# *  **Safety:**  Consider safety features and ratings for the year.
# *  **Insurance:**  Insurance premiums can be higher for older vehicles.
# *  **Inspection:**  Before you buy, have a mechanic inspect the car thoroughly.
#
# I hope this detailed breakdown helps you make an informed decision on your 1988-1989 Pontiac Bonneville purchase!  Good luck with your search!

# %%
# Ask the model directly in a zero-shot prompt.

prompt = "From what newsgroup does the following message originate?"
baseline_response = client.models.generate_content(
    model="gemini-1.5-flash-001",
    contents=[prompt, sample_row])
print(baseline_response.text)
# Out:
# This message likely originates from a newsgroup related to **Buick automobiles**, specifically the **Bonneville model**.
#
# Here's why:
#
# * **The topic:** The message clearly focuses on the 1988-1989 Buick Bonneville.
# * **The terminology:** The message uses model-specific terms like LE, SE, LSE, SSE, and SSEi, which are all trim levels of the Bonneville during those years.
# * **The inquiry:** The writer seeks information about the differences between these trim levels and their value, which is typical of car enthusiasts and potential buyers.
#
# Therefore, the most likely newsgroups this message originated from are:
#
# * **alt.autos.buick**
# * **rec.autos.buick**
#
# These newsgroups would be frequented by Buick owners and enthusiasts, making them the ideal places to ask questions about specific models like the Bonneville.

# %%
from google.api_core import retry

# You can use a system instruction to do more direct prompting, and get a
# more succinct answer.

system_instruct = """
You are a classification service. You will be passed input that represents
a newsgroup post and you must respond with the newsgroup from which the post
originates.
"""

# Define a helper to retry when per-minute quota is reached.
is_retriable = lambda e: (isinstance(e, genai.errors.APIError) and e.code in {429, 503})

# If you want to evaluate your own technique, replace this body of this function
# with your model, prompt and other code and return the predicted answer.
@retry.Retry(predicate=is_retriable)
def predict_label(post: str) -> str:
    response = client.models.generate_content(
        model="gemini-1.5-flash-001",
        config=types.GenerateContentConfig(
            system_instruction=system_instruct),
        contents=post)

    rc = response.candidates[0]

    # Any errors, filters, recitation, etc we can mark as a general error
    if rc.finish_reason.name != "STOP":
        return "(error)"
    else:
        # Clean up the response.
        return response.text.strip()


prediction = predict_label(sample_row)

print(prediction)
print()
print("Correct!" if prediction == sample_label else "Incorrect.")
# Out:
# rec.autos.misc
#
# Incorrect.

# %%
import tqdm
from tqdm.rich import tqdm as tqdmr
import warnings

# Enable tqdm features on Pandas.
tqdmr.pandas()

# But suppress the experimental warning
warnings.filterwarnings("ignore", category=tqdm.TqdmExperimentalWarning)


# Further sample the test data to be mindful of the free-tier quota.
df_baseline_eval = sample_data(df_test, 2, '.*')

# Make predictions using the sampled data.
df_baseline_eval['Prediction'] = df_baseline_eval['Text'].progress_apply(predict_label)

# And calculate the accuracy.
accuracy = (df_baseline_eval["Class Name"] == df_baseline_eval["Prediction"]).sum() / len(df_baseline_eval)
print(f"Accuracy: {accuracy:.2%}")
# Out:
# C:\Users\Devisha\AppData\Roaming\Python\Python313\site-packages\rich\live.py:231: UserWarning: install "ipywidgets"
# for Jupyter support
#   warnings.warn('install "ipywidgets" for Jupyter support')
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# Accuracy: 12.50%

# %%
df_baseline_eval
# Out:
#                                                  Text  Label  \
# 0   Re: MR2 - noisy engine.\n\nJust a quick note o...      7
# 1   Re: Lexus and Infiniti\n\n (Keith Chong) write...      7
# 2   Re: Countersteering sans Hands\n\nIn article ,...      8
# 3   A Kinder, Gentler BMW Mailing List\n\nI know t...      8
# 4   Re: Hits Stolen -- First Base 1992\n\nIn <>  (...      9
# 5   Re: ugliest swing\n\n\tUgliest swing..I am not...      9
# 6   Re: Wings News and Playoff Thoughts\n\nI wrote...     10
# 7   Bowman needs credit\n\nDuring the first three ...     10
# 8   What would happen if export restrictions viola...     11
# 9   Hidden Markov Modeling\n\nIn the article "At l...     11
# 10  Circuit List (locations)\n\n\n\tHere is a list...     12
# 11  Re: How universal are phones these days?\n\nIn...     12
# 12  Re: INFO: Colonics and Purification?\n\nIn art...     13
# 13  Allergies and stuff (Was: Is MSG sensitivity s...     13
# 14  Re: Space Marketing would be wonderfull.\n\nIn...     14
# 15  Re: Philosophy Quest.  How Boldly?\n\nIn artic...     14
#
#             Class Name              Prediction
# 0            rec.autos        rec.autos.toyota
# 1            rec.autos          rec.autos.misc
# 2      rec.motorcycles         rec.motorcycles
# 3      rec.motorcycles     rec.motorcycles.bmw
# 4   rec.sport.baseball      rec.sport.baseball
# 5   rec.sport.baseball     rec.sports.baseball
# 6     rec.sport.hockey       rec.sports.hockey
# 7     rec.sport.hockey             hockey.misc
# 8            sci.crypt                 (error)
# 9            sci.crypt     comp.ai.neural-nets
# 10     sci.electronics  rec.electronics.design
# 11     sci.electronics       rec.travel.europe
# 12             sci.med              alt.health
# 13             sci.med            alt.food.veg
# 14           sci.space             alt.atheism
# 15           sci.space             alt.atheism

# %%
from collections.abc import Iterable
import random

# Convert the data frame into a dataset suitable for tuning.
input_data = {'examples': 
    df_train[['Text', 'Class Name']]
      .rename(columns={'Text': 'textInput', 'Class Name': 'output'})
      .to_dict(orient='records')
 }

# If you are re-running this lab, add your model_id here.
model_id = None

# Or try and find a recent tuning job.
if not model_id:
  queued_model = None
  # Newest models first.
  for m in reversed(client.tunings.list()):
    # Only look at newsgroup classification models.
    if m.name.startswith('tunedModels/newsgroup-classification-model'):
      # If there is a completed model, use the first (newest) one.
      if m.state.name == 'JOB_STATE_SUCCEEDED':
        model_id = m.name
        print('Found existing tuned model to reuse.')
        break
      elif m.state.name == 'JOB_STATE_RUNNING' and not queued_model:
        # If there's a model still queued, remember the most recent one.
        queued_model = m.name
  else:
    if queued_model:
      model_id = queued_model
      print('Found queued model, still waiting.')

# Upload the training data and queue the tuning job.
if not model_id:
    tuning_op = client.tunings.tune(
        base_model="models/gemini-1.5-flash-001-tuning",
        training_dataset=input_data,
        config=types.CreateTuningJobConfig(
            tuned_model_display_name="Newsgroup classification model",
            batch_size=16,
            epoch_count=2,
        ),
    )

    print(tuning_op.state)
    model_id = tuning_op.name

print(model_id)
# Out:
# Found queued model, still waiting.
# tunedModels/newsgroup-classification-model-3fdm66aef

# %%
import datetime
import time


MAX_WAIT = datetime.timedelta(minutes=10)

while not (tuned_model := client.tunings.get(name=model_id)).has_ended:

    print(tuned_model.state)
    time.sleep(60)

    # Don't wait too long. Use a public model if this is going to take a while.
if datetime.datetime.now(datetime.timezone.utc) - tuned_model.create_time > MAX_WAIT:
    print("Taking a shortcut, using a previously prepared model.")
    model_id = "tunedModels/newsgroup-classification-model-ltenbi1b"
    tuned_model = client.tunings.get(name=model_id)
    # Exit the loop by setting the tuned_model to a completed state
    tuned_model.has_ended = True


print(f"Done! The model state is: {tuned_model.state.name}")

if not tuned_model.has_succeeded and tuned_model.error:
    print("Error:", tuned_model.error)
# Out:
# JobState.JOB_STATE_RUNNING
# JobState.JOB_STATE_RUNNING
# JobState.JOB_STATE_RUNNING
# JobState.JOB_STATE_RUNNING
# JobState.JOB_STATE_RUNNING
# JobState.JOB_STATE_RUNNING
# JobState.JOB_STATE_RUNNING
# JobState.JOB_STATE_RUNNING
# JobState.JOB_STATE_RUNNING
# JobState.JOB_STATE_RUNNING
# JobState.JOB_STATE_RUNNING
# JobState.JOB_STATE_RUNNING
# JobState.JOB_STATE_RUNNING
# JobState.JOB_STATE_RUNNING
# JobState.JOB_STATE_RUNNING
# JobState.JOB_STATE_RUNNING
# JobState.JOB_STATE_RUNNING
# JobState.JOB_STATE_RUNNING
# JobState.JOB_STATE_RUNNING
# JobState.JOB_STATE_RUNNING
# JobState.JOB_STATE_RUNNING
# JobState.JOB_STATE_RUNNING
# JobState.JOB_STATE_RUNNING
# JobState.JOB_STATE_RUNNING
# JobState.JOB_STATE_RUNNING
# JobState.JOB_STATE_RUNNING
# JobState.JOB_STATE_RUNNING
# JobState.JOB_STATE_RUNNING
# JobState.JOB_STATE_RUNNING
# JobState.JOB_STATE_RUNNING
# JobState.JOB_STATE_RUNNING
# JobState.JOB_STATE_RUNNING
# JobState.JOB_STATE_RUNNING
# JobState.JOB_STATE_RUNNING
# JobState.JOB_STATE_RUNNING
# JobState.JOB_STATE_RUNNING
# JobState.JOB_STATE_RUNNING
# JobState.JOB_STATE_RUNNING
# JobState.JOB_STATE_RUNNING
# JobState.JOB_STATE_RUNNING
# JobState.JOB_STATE_RUNNING
# JobState.JOB_STATE_RUNNING
# JobState.JOB_STATE_RUNNING
# JobState.JOB_STATE_RUNNING
# JobState.JOB_STATE_RUNNING
# JobState.JOB_STATE_RUNNING
# JobState.JOB_STATE_RUNNING
# JobState.JOB_STATE_RUNNING
# JobState.JOB_STATE_RUNNING
# JobState.JOB_STATE_RUNNING
# JobState.JOB_STATE_RUNNING
# JobState.JOB_STATE_RUNNING
# JobState.JOB_STATE_RUNNING
# JobState.JOB_STATE_RUNNING
# JobState.JOB_STATE_RUNNING
# JobState.JOB_STATE_RUNNING
# JobState.JOB_STATE_RUNNING
# JobState.JOB_STATE_RUNNING
# JobState.JOB_STATE_RUNNING
# JobState.JOB_STATE_RUNNING
# JobState.JOB_STATE_RUNNING
# JobState.JOB_STATE_RUNNING
# JobState.JOB_STATE_RUNNING
# JobState.JOB_STATE_RUNNING
# JobState.JOB_STATE_RUNNING
# JobState.JOB_STATE_RUNNING
# JobState.JOB_STATE_RUNNING
# JobState.JOB_STATE_RUNNING
# JobState.JOB_STATE_RUNNING
# JobState.JOB_STATE_RUNNING
# JobState.JOB_STATE_RUNNING
# JobState.JOB_STATE_RUNNING
# JobState.JOB_STATE_RUNNING
# JobState.JOB_STATE_RUNNING
# JobState.JOB_STATE_RUNNING
# JobState.JOB_STATE_RUNNING
# JobState.JOB_STATE_RUNNING
# JobState.JOB_STATE_RUNNING
# JobState.JOB_STATE_RUNNING
# JobState.JOB_STATE_RUNNING
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[15], line 10
#       7 while not (tuned_model := client.tunings.get(name=model_id)).has_ended:
#       9     print(tuned_model.state)
# ---> 10     time.sleep(60)
#      12     # Don't wait too long. Use a public model if this is going to take a while.
#      13 if datetime.datetime.now(datetime.timezone.utc) - tuned_model.create_time > MAX_WAIT:
#
# KeyboardInterrupt:

# %%
new_text = """
First-timer looking to get out of here.

Hi, I'm writing about my interest in travelling to the outer limits!

What kind of craft can I buy? What is easiest to access from this 3rd rock?

Let me know how to do that please.
"""

response = client.models.generate_content(
    model=model_id, contents=new_text)

print(response.text)
# Out:
# ---------------------------------------------------------------------------
# ClientError                               Traceback (most recent call last)
# Cell In[16], line 11
#       1 new_text = """
#       2 First-timer looking to get out of here.
#       3
#    (...)      8 Let me know how to do that please.
#       9 """
# ---> 11 response = client.models.generate_content(
#      12     model=model_id, contents=new_text)
#      14 print(response.text)
#
# File ~\AppData\Roaming\Python\Python313\site-packages\google\genai\models.py:5370, in Models.generate_content(self, model, contents, config)
#    5368 while remaining_remote_calls_afc > 0:
#    5369   i += 1
# -> 5370   response = self._generate_content(
#    5371       model=model, contents=contents, config=config
#    5372   )
#    5373   logger.info(f'AFC remote call {i} is done.')
#    5374   remaining_remote_calls_afc -= 1
#
# File ~\AppData\Roaming\Python\Python313\site-packages\google\genai\models.py:4338, in Models._generate_content(self, model, contents, config)
#    4335 request_dict = _common.convert_to_dict(request_dict)
#    4336 request_dict = _common.encode_unserializable_types(request_dict)
# -> 4338 response_dict = self._api_client.request(
#    4339     'post', path, request_dict, http_options
#    4340 )
#    4342 if self._api_client.vertexai:
#    4343   response_dict = _GenerateContentResponse_from_vertex(
#    4344       self._api_client, response_dict
#    4345   )
#
# File ~\AppData\Roaming\Python\Python313\site-packages\google\genai\_api_client.py:640, in BaseApiClient.request(self, http_method, path, request_dict, http_options)
#     630 def request(
#     631     self,
#     632     http_method: str,
#    (...)    635     http_options: Optional[HttpOptionsOrDict] = None,
#     636 ):
#     637   http_request = self._build_request(
#     638       http_method, path, request_dict, http_options
#     639   )
# --> 640   response = self._request(http_request, stream=False)
#     641   json_response = response.json
#     642   if not json_response:
#
# File ~\AppData\Roaming\Python\Python313\site-packages\google\genai\_api_client.py:569, in BaseApiClient._request(self, http_request, stream)
#     561 else:
#     562   response = self._httpx_client.request(
#     563       method=http_request.method,
#     564       url=http_request.url,
#    (...)    567       timeout=http_request.timeout,
#     568   )
# --> 569   errors.APIError.raise_for_response(response)
#     570   return HttpResponse(
#     571       response.headers, response if stream else [response.text]
#     572   )
#
# File ~\AppData\Roaming\Python\Python313\site-packages\google\genai\errors.py:106, in APIError.raise_for_response(cls, response)
#     104 status_code = response.status_code
#     105 if 400 <= status_code < 500:
# --> 106   raise ClientError(status_code, response)
#     107 elif 500 <= status_code < 600:
#     108   raise ServerError(status_code, response)
#
# ClientError: 400 INVALID_ARGUMENT. {'error': {'code': 400, 'message': 'Tuned model tunedModels/newsgroup-classification-model-3fdm66aef is not ready to use.', 'status': 'INVALID_ARGUMENT'}}

# %%
@retry.Retry(predicate=is_retriable)
def classify_text(text: str) -> str:
    """Classify the provided text into a known newsgroup."""
    response = client.models.generate_content(
        model=model_id, contents=text)
    rc = response.candidates[0]

    # Any errors, filters, recitation, etc we can mark as a general error
    if rc.finish_reason.name != "STOP":
        return "(error)"
    else:
        return rc.content.parts[0].text
    # The sampling here is just to minimise your quota usage. If you can, you should
# evaluate the whole test set with `df_model_eval = df_test.copy()`.
df_model_eval = sample_data(df_test, 4, '.*')

df_model_eval["Prediction"] = df_model_eval["Text"].progress_apply(classify_text)

accuracy = (df_model_eval["Class Name"] == df_model_eval["Prediction"]).sum() / len(df_model_eval)
print(f"Accuracy: {accuracy:.2%}")

# %%
# Calculate the *input* cost of the baseline model with system instructions.
sysint_tokens = client.models.count_tokens(
    model='gemini-1.5-flash-001', contents=[system_instruct, sample_row]
).total_tokens
print(f'System instructed baseline model: {sysint_tokens} (input)')

# Calculate the input cost of the tuned model.
tuned_tokens = client.models.count_tokens(model=tuned_model.base_model, contents=sample_row).total_tokens
print(f'Tuned model: {tuned_tokens} (input)')

savings = (sysint_tokens - tuned_tokens) / tuned_tokens
print(f'Token savings: {savings:.2%}')  # Note that this is only n=1.

# %%
baseline_token_output = baseline_response.usage_metadata.candidates_token_count
print('Baseline (verbose) output tokens:', baseline_token_output)

tuned_model_output = client.models.generate_content(
    model=model_id, contents=sample_row)
tuned_tokens_output = tuned_model_output.usage_metadata.candidates_token_count
print('Tuned output tokens:', tuned_tokens_output)
